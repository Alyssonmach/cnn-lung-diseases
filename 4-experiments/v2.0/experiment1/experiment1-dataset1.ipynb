# %% [markdown]
# # Experimento 1 - Atualizado
# ***
# - Conjuntos de dados: Montgomery
# - Aplicando mudança de escala típica nas imagens

# %% [markdown]
# ### Importando os pacotes necessários

# %%
import glob
import re
from tqdm import tqdm
import urllib.request
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Pré-processando os dados

# %%
# coletando o caminho dos arquivos dos dados do hospital montgomery
filelist_montgomery = glob.glob('/content/drive/MyDrive/Montgomery/MontgomerySet/CXR_png/*.png')

# %%
# quantidade de imagens disponíveis no dataset
print('quantidade de imagens:', str(len(filelist_montgomery)))
# Out:
# quantidade de imagens: 138

# %%
def extract_label(file_list):
    
    # inicializando uma lista vazia
    labels = []
    
    # iterando na lista de arquivos
    for file in tqdm(file_list):
        # detectando as classes presentes no nome da imagem
        current_label = re.findall('[0-9]{4}_(.+?).png', file)
        # adicionando a lista de rótulos as classes correspondentes a cada uma das imagens
        if current_label[0] == '0':
          labels.append('normal')
        else:
          labels.append('abnormal')
        
    return labels

# %%
# extraindo os rótulos
labels = extract_label(filelist_montgomery)
# Out:
# 100%|██████████| 138/138 [00:00<00:00, 129055.51it/s]

# %%
# visualizando a quantidade de rótulos
print('quantidade de rótulos:', str(len(labels)))
# Out:
# quantidade de rótulos: 138

# %%
# criando um dataframe com os caminhos das imagens
full_data = pd.DataFrame(filelist_montgomery, columns = ['filepath'])
# adicionando os rótulos em cada imagem
full_data['target'] = labels

# %%
# separando os dados de treinamento e de teste
train_df, test_df = train_test_split(full_data, stratify = full_data['target'],
                                     test_size = 0.2, random_state = 42)

# %%
# separando os dados de validação dos dados de treinamento
train_df, validation_df = train_test_split(train_df, stratify = train_df['target'],
                                           test_size = 0.2, random_state = 42)

# %%
# visualizando a quantidade de dados
print('quantidade de imagens de treinamento:', len(train_df['filepath']))
print('quantidade de rótulos de treinamento:', len(train_df['target']))
print('quantidade de imagens de teste:', len(test_df['filepath']))
print('quantidade de rótulos de teste:', len(test_df['target']))
print('quantidade de imagens de validação:', len(validation_df['filepath']))
print('quantidade de rótulos de validação:', len(validation_df['target']))
# Out:
# quantidade de imagens de treinamento: 88
# quantidade de rótulos de treinamento: 88
# quantidade de imagens de teste: 28
# quantidade de rótulos de teste: 28
# quantidade de imagens de validação: 22
# quantidade de rótulos de validação: 22

# %%
# observando a distribuição na quantidade de dados disponíveis
print(train_df['target'].value_counts())
# fazendo um balanceamento nos pesos das classes
class_weight = {0: (51+37)/51, 1: (51+37)/37}
# Out:
# normal      51
# abnormal    37
# Name: target, dtype: int64

# %% [markdown]
# ### Aplicando mudança de escala típica

# %%
# normalizando as imagens de treinamento e aplicando aumento de dados
image_generator = ImageDataGenerator(rescale = 1./255., rotation_range = 10, zoom_range = 0.2)

# criando o gerador de imagens de treinamento 
train_generator = image_generator.flow_from_dataframe(
                                                      dataframe = train_df,
                                                      directory = '',
                                                      x_col = 'filepath',
                                                      y_col = 'target',
                                                      batch_size = 32,
                                                      seed = 42,
                                                      shuffle = True,
                                                      class_mode = 'categorical',
                                                      target_size = (256, 256))

# normalizando as imagens de teste e validação
test_datagen = ImageDataGenerator(rescale = 1./255.)

# criando o gerador de imagens de validação 
valid_generator = test_datagen.flow_from_dataframe(
                                                      dataframe = validation_df,
                                                      directory = '.', 
                                                      x_col = 'filepath',
                                                      y_col = 'target',
                                                      batch_size = 22,
                                                      seed = 42,
                                                      shuffle = True,
                                                      class_mode = 'categorical',
                                                      target_size = (256, 256))

test_generator = test_datagen.flow_from_dataframe(
                                                  dataframe = test_df, 
                                                  directory = '.',
                                                  x_col = 'filepath',
                                                  y_col = 'target',
                                                  batch_size = 28,
                                                  seed = 42,
                                                  shuffle = True,
                                                  class_mode = 'categorical',
                                                  target_size = (256, 256))
# Out:
# Found 88 validated image filenames belonging to 2 classes.
# Found 22 validated image filenames belonging to 2 classes.
# Found 28 validated image filenames belonging to 2 classes.

# %%
# visualizando a ordem dos atributos numéricos das classes
train_generator.class_indices
# Out:
# {'abnormal': 0, 'normal': 1}

# %% [markdown]
# ### Preparando a rede neural convolucional

# %%
# baixando os pesos treinados da rede inception
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5 \
    -O /tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# --2021-04-13 01:00:51--  https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.125.128, 74.125.203.128, 64.233.188.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.125.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87910968 (84M) [application/x-hdf]
# Saving to: ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’
#
# /tmp/inception_v3_w 100%[===================>]  83.84M   291MB/s    in 0.3s
#
# 2021-04-13 01:00:52 (291 MB/s) - ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’ saved [87910968/87910968]

# %%
# referenciando o local em que os pesos estão armazenados
local_weights_file = '/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'

# carregando a arquitetura inception pré-treinada
pre_trained_model = InceptionV3(input_shape = (256, 256, 3), 
                                include_top = False, 
                                weights = None)

# carregando os pesos treinados com outros dados 
pre_trained_model.load_weights(local_weights_file)

# definindo as flags iniciais  
pre_trained_model.trainable = True
set_trainable = False

# para a arquitetura inception, a rede será retreinada a partir da camada 'mixed6'
for layer in pre_trained_model.layers:
    if layer.name == 'mixed6':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# obtendo a última camada como sendo a nomeada por 'mixed7'
last_layer = pre_trained_model.get_layer('mixed7')
last_output = last_layer.output

# %%
# definindo uma camada de achatamento
x = layers.GlobalAveragePooling2D()(last_output)
# adicionando uma camada densa com 512 neurônios
x = layers.Dense(units = 512, activation = tf.nn.relu)(x)     
# conecatando a rede uma camada com 128 neurônios e função de ativação relu
x = layers.Dense(units = 256, activation = tf.nn.relu)(x) 
# aplicando uma camada de dropout com uma taxa de 20% (normalização)
x = layers.Dropout(rate = 0.2)(x)            
# adicionando uma camada de saída com um neurônio e uma função de ativação sigmoide
x = layers.Dense(units = 2, activation = tf.nn.softmax)(x)           

# conecatando as camadas definidas acima com a arquitetura inception
model = Model(pre_trained_model.input, x) 

# compilando a rede 
model.compile(optimizer = optimizers.RMSprop(learning_rate = 0.0001), loss = 'categorical_crossentropy', 
              metrics = ['acc'])

# %%
# definindo o caminho pelo qual os pesos serão armazenados 
filepath = "transferlearning_weights.hdf5"
# callback para salvar o melhor valor dos pesos em relação ao desempenho com os dados de validação 
checkpoint = ModelCheckpoint(filepath, monitor = 'val_acc', verbose = 1, save_best_only = True, mode = 'max')

# %%
# definindo um array de callbacks
callbacks = [checkpoint]

# %%
# treinando a rede neural convolucional
history = model.fit_generator(train_generator, steps_per_epoch = 88 // 32, 
                              validation_data = valid_generator, validation_steps = 1,
                              callbacks = callbacks, epochs = 100, class_weight = class_weight, 
                              use_multiprocessing = True, workers = 8)
# Out:
# Epoch 1/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss:
WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.1635 - acc: 0.9792 - val_loss: 0.6573 - val_acc: 0.7273
#
# Epoch 00033: val_acc did not improve from 0.72727
# Epoch 34/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.1161 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.1206 - acc: 1.0000 - val_loss: 0.6308 - val_acc: 0.7273
#
# Epoch 00034: val_acc did not improve from 0.72727
# Epoch 35/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0834 - acc: 1.0000 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0849 - acc: 1.0000 - val_loss: 0.5693 - val_acc: 0.7273
#
# Epoch 00035: val_acc did not improve from 0.72727
# Epoch 36/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.1676 - acc: 0.9688WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.1621 - acc: 0.9688 - val_loss: 0.5786 - val_acc: 0.7273
#
# Epoch 00036: val_acc did not improve from 0.72727
# Epoch 37/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0511 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 8s/step - loss: 0.0511 - acc: 1.0000 - val_loss: 0.6583 - val_acc: 0.7273
#
# Epoch 00037: val_acc did not improve from 0.72727
# Epoch 38/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0547 - acc: 1.0000 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0535 - acc: 1.0000 - val_loss: 0.6156 - val_acc: 0.7273
#
# Epoch 00038: val_acc did not improve from 0.72727
# Epoch 39/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0541 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 9s/step - loss: 0.0527 - acc: 1.0000 - val_loss: 0.6889 - val_acc: 0.7273
#
# Epoch 00039: val_acc did not improve from 0.72727
# Epoch 40/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0526 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0524 - acc: 1.0000 - val_loss: 0.5350 - val_acc: 0.8182
#
# Epoch 00040: val_acc improved from 0.72727 to 0.81818, saving model to transferlearning_weights.hdf5
# Epoch 41/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0607 - acc: 0.9911WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0675 - acc: 0.9881 - val_loss: 0.2728 - val_acc: 0.9091
#
# Epoch 00041: val_acc improved from 0.81818 to 0.90909, saving model to transferlearning_weights.hdf5
# Epoch 42/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.1303 - acc: 0.9702WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 8s/step - loss: 0.1175 - acc: 0.9742 - val_loss: 0.3776 - val_acc: 0.8636
#
# Epoch 00042: val_acc did not improve from 0.90909
# Epoch 43/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0391 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0406 - acc: 1.0000 - val_loss: 0.3198 - val_acc: 0.9091
#
# Epoch 00043: val_acc did not improve from 0.90909
# Epoch 44/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0323 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0320 - acc: 1.0000 - val_loss: 0.2926 - val_acc: 0.9091
#
# Epoch 00044: val_acc did not improve from 0.90909
# Epoch 45/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0263 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0260 - acc: 1.0000 - val_loss: 0.3563 - val_acc: 0.9091
#
# Epoch 00045: val_acc did not improve from 0.90909
# Epoch 46/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0365 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0353 - acc: 1.0000 - val_loss: 0.3429 - val_acc: 0.9091
#
# Epoch 00046: val_acc did not improve from 0.90909
# Epoch 47/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0172 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0180 - acc: 1.0000 - val_loss: 0.3505 - val_acc: 0.9091
#
# Epoch 00047: val_acc did not improve from 0.90909
# Epoch 48/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0187 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0183 - acc: 1.0000 - val_loss: 0.3380 - val_acc: 0.9091
#
# Epoch 00048: val_acc did not improve from 0.90909
# Epoch 49/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0154 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0154 - acc: 1.0000 - val_loss: 0.3488 - val_acc: 0.9091
#
# Epoch 00049: val_acc did not improve from 0.90909
# Epoch 50/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0192 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0185 - acc: 1.0000 - val_loss: 0.3125 - val_acc: 0.9091
#
# Epoch 00050: val_acc did not improve from 0.90909
# Epoch 51/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0608 - acc: 0.9911WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0639 - acc: 0.9881 - val_loss: 0.2694 - val_acc: 0.9091
#
# Epoch 00051: val_acc did not improve from 0.90909
# Epoch 52/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0139 - acc: 1.0000 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.2884 - val_acc: 0.9091
#
# Epoch 00052: val_acc did not improve from 0.90909
# Epoch 53/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0129 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0136 - acc: 1.0000 - val_loss: 0.2480 - val_acc: 0.9545
#
# Epoch 00053: val_acc improved from 0.90909 to 0.95455, saving model to transferlearning_weights.hdf5
# Epoch 54/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0119 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0118 - acc: 1.0000 - val_loss: 0.2361 - val_acc: 0.9091
#
# Epoch 00054: val_acc did not improve from 0.95455
# Epoch 55/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0096 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0099 - acc: 1.0000 - val_loss: 0.2627 - val_acc: 0.9545
#
# Epoch 00055: val_acc did not improve from 0.95455
# Epoch 56/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0078 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0078 - acc: 1.0000 - val_loss: 0.2665 - val_acc: 0.9545
#
# Epoch 00056: val_acc did not improve from 0.95455
# Epoch 57/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0142 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0133 - acc: 1.0000 - val_loss: 0.2554 - val_acc: 0.9545
#
# Epoch 00057: val_acc did not improve from 0.95455
# Epoch 58/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0059 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 7s/step - loss: 0.0059 - acc: 1.0000 - val_loss: 0.2664 - val_acc: 0.9545
#
# Epoch 00058: val_acc did not improve from 0.95455
# Epoch 59/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0079 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 7s/step - loss: 0.0081 - acc: 1.0000 - val_loss: 0.2845 - val_acc: 0.9545
#
# Epoch 00059: val_acc did not improve from 0.95455
# Epoch 60/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0131 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0124 - acc: 1.0000 - val_loss: 0.2799 - val_acc: 0.9545
#
# Epoch 00060: val_acc did not improve from 0.95455
# Epoch 61/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0040 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.2824 - val_acc: 0.9091
#
# Epoch 00061: val_acc did not improve from 0.95455
# Epoch 62/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0094 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0093 - acc: 1.0000 - val_loss: 0.2322 - val_acc: 0.9091
#
# Epoch 00062: val_acc did not improve from 0.95455
# Epoch 63/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0029 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 8s/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.2412 - val_acc: 0.9545
#
# Epoch 00063: val_acc did not improve from 0.95455
# Epoch 64/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0116 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0139 - acc: 1.0000 - val_loss: 0.5083 - val_acc: 0.8182
#
# Epoch 00064: val_acc did not improve from 0.95455
# Epoch 65/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0070 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 7s/step - loss: 0.0074 - acc: 1.0000 - val_loss: 0.5093 - val_acc: 0.7727
#
# Epoch 00065: val_acc did not improve from 0.95455
# Epoch 66/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0414 - acc: 0.9922WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 7s/step - loss: 0.0540 - acc: 0.9896 - val_loss: 0.3473 - val_acc: 0.9545
#
# Epoch 00066: val_acc did not improve from 0.95455
# Epoch 67/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0061 - acc: 1.0000 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.3447 - val_acc: 0.9545
#
# Epoch 00067: val_acc did not improve from 0.95455
# Epoch 68/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0042 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 8s/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.3499 - val_acc: 0.9545
#
# Epoch 00068: val_acc did not improve from 0.95455
# Epoch 69/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0026 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.3452 - val_acc: 0.9545
#
# Epoch 00069: val_acc did not improve from 0.95455
# Epoch 70/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0035 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.3222 - val_acc: 0.9545
#
# Epoch 00070: val_acc did not improve from 0.95455
# Epoch 71/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0025 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# ...
# 2/2 [==============================] - ETA: 0s - loss: 0.0100 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0092 - acc: 1.0000 - val_loss: 0.5259 - val_acc: 0.9091
#
# Epoch 00077: val_acc did not improve from 0.95455
# Epoch 78/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0046 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 7s/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.4426 - val_acc: 0.8636
#
# Epoch 00078: val_acc did not improve from 0.95455
# Epoch 79/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0021 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.4319 - val_acc: 0.8636
#
# Epoch 00079: val_acc did not improve from 0.95455
# Epoch 80/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0025 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.4034 - val_acc: 0.9091
#
# Epoch 00080: val_acc did not improve from 0.95455
# Epoch 81/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0021 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 8s/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.3980 - val_acc: 0.9091
#
# Epoch 00081: val_acc did not improve from 0.95455
# Epoch 82/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0026 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.4265 - val_acc: 0.9091
#
# Epoch 00082: val_acc did not improve from 0.95455
# Epoch 83/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0010 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.4250 - val_acc: 0.9091
#
# Epoch 00083: val_acc did not improve from 0.95455
# Epoch 84/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0018 - acc: 1.0000    WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.4260 - val_acc: 0.8636
#
# Epoch 00084: val_acc did not improve from 0.95455
# Epoch 85/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0011 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.4273 - val_acc: 0.8636
#
# Epoch 00085: val_acc did not improve from 0.95455
# Epoch 86/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0017 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 14s 6s/step - loss: 0.0016 - acc: 1.0000 - val_loss: 0.4161 - val_acc: 0.9091
#
# Epoch 00086: val_acc did not improve from 0.95455
# Epoch 87/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0022 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.4879 - val_acc: 0.8636
#
# Epoch 00087: val_acc did not improve from 0.95455
# Epoch 88/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0051 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.5572 - val_acc: 0.8636
#
# Epoch 00088: val_acc did not improve from 0.95455
# Epoch 89/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0107 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 7s/step - loss: 0.0100 - acc: 1.0000 - val_loss: 0.5512 - val_acc: 0.8182
#
# Epoch 00089: val_acc did not improve from 0.95455
# Epoch 90/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0015 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 9s/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.5875 - val_acc: 0.7727
#
# Epoch 00090: val_acc did not improve from 0.95455
# Epoch 91/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 6.2584e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 6.8313e-04 - acc: 1.0000 - val_loss: 0.5862 - val_acc: 0.7727
#
# Epoch 00091: val_acc did not improve from 0.95455
# Epoch 92/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0017 - acc: 1.0000     WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.7976 - val_acc: 0.7727
#
# Epoch 00092: val_acc did not improve from 0.95455
# Epoch 93/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 6.8528e-04 - acc: 1.0000 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 6.7709e-04 - acc: 1.0000 - val_loss: 0.8031 - val_acc: 0.7727
#
# Epoch 00093: val_acc did not improve from 0.95455
# Epoch 94/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0026 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.9834 - val_acc: 0.7727
#
# Epoch 00094: val_acc did not improve from 0.95455
# Epoch 95/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 0.0046 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.5935 - val_acc: 0.7727
#
# Epoch 00095: val_acc did not improve from 0.95455
# Epoch 96/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 2.5068e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 16s 6s/step - loss: 2.5936e-04 - acc: 1.0000 - val_loss: 0.6040 - val_acc: 0.7727
#
# Epoch 00096: val_acc did not improve from 0.95455
# Epoch 97/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 6.0537e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 8s/step - loss: 5.6629e-04 - acc: 1.0000 - val_loss: 0.6084 - val_acc: 0.7727
#
# Epoch 00097: val_acc did not improve from 0.95455
# Epoch 98/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 5.1510e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 5.1781e-04 - acc: 1.0000 - val_loss: 0.5772 - val_acc: 0.7727
#
# Epoch 00098: val_acc did not improve from 0.95455
# Epoch 99/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 3.4055e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 3.3865e-04 - acc: 1.0000 - val_loss: 0.5856 - val_acc: 0.7727
#
# Epoch 00099: val_acc did not improve from 0.95455
# Epoch 100/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - ETA: 0s - loss: 5.6407e-04 - acc: 1.0000WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 2/2 [==============================] - 15s 6s/step - loss: 5.8753e-04 - acc: 1.0000 - val_loss: 0.6209 - val_acc: 0.7727
#
# Epoch 00100: val_acc did not improve from 0.95455

# %% [markdown]
# ### Salvando o modelo desenvolvido

# %%
# carregando o melhor peso obtido para o modelo
best_model = model
best_model.load_weights('/content/transferlearning_weights.hdf5')

# %%
# salvando os dois modelos obtidos durante o treinamento
model.save('model1')
best_model.save('model2')
# Out:
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model2/assets

# %%
# carregando o melhor modelo para realização de testes de desempenho
model = tf.keras.models.load_model('/content/drive/MyDrive/experimentos/v2.0-exp1-ds1/model2')

# %% [markdown]
# ### Métricas de avaliação do modelo

# %%
# testando a capacidade de predição do modelo com os dados de teste
model.evaluate_generator(test_generator)
# Out:
# [0.582036018371582, 0.8214285969734192]

# %%
# carregando os dados de teste
(x, y) = test_generator[0]

# %%
# realizando a predição para os dados de teste
predict = model.predict(x)

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix

def thresholds(limiar, predict):
  '''predição para diferentes thresholds'''

  predict_ = []
  for i in predict:
    if i > limiar:
      predict_.append(1)
    else:
      predict_.append(0)
  
  return predict_

def precision_recall_accuracy_curve(predict, y):
  ''' Relaciona a curva da Precisão, Sensibilidade e Acurácia em relação a diferentes Thresholds'''

  limiares = np.arange(0, 1, 0.05)
  predicts = []
  precisions = []
  recalls = []
  accuracy = []
  flag = 0
  for i in limiares:
    predicts.append(thresholds(i, predict))
    precisions.append(precision_score(predicts[flag], y))
    recalls.append(recall_score(predicts[flag], y))
    accuracy.append(accuracy_score(predicts[flag], y))
    flag += 1
  
  return precisions, recalls, accuracy

def plot_precision_recall_accuracy_curve(precisions, recalls, accuracy):
  '''Plotando a curva de Precisão, Sensibilidade e Acurácia'''

  plt.figure(figsize = (10,5))
  plt.plot(np.arange(0, 1, 0.05), precisions, label = 'Precision')
  plt.plot(np.arange(0, 1, 0.05), recalls, label = 'Recall')
  plt.plot(np.arange(0, 1, 0.05), accuracy, label = 'Accuracy')
  plt.title('Precisão, Sensibilidade e Acurácia para diferentes Thresholds')
  plt.xlabel('Thresholds')
  plt.legend()
  plt.savefig('curve-analysis')

  return None

def best_metrics(threshold, predict, y):
  '''Melhores valores para o threshold escolhido'''

  predict_ = thresholds(threshold, predict)
  print('Matriz de Confusão:\n', confusion_matrix(predict_, y))
  print('Acurácia:', accuracy_score(predict_, y))
  print('Precisão', precision_score(predict_, y))
  print('Sensibilidade:', recall_score(predict_, y)) 
  print('F1_Score:', f1_score(predict_, y))

  return None

# %%
# plotando a curva da Precisão, Sensibilidade e Acurácia 
precisions, recalls, accuracy = precision_recall_accuracy_curve(predict[:, 0], y[:, 0])
plot_precision_recall_accuracy_curve(precisions, recalls, accuracy)

# %%
# plotando a curva da Precisão, Sensibilidade e Acurácia 
precisions, recalls, accuracy = precision_recall_accuracy_curve(predict[:, 1], y[:, 1])
plot_precision_recall_accuracy_curve(precisions, recalls, accuracy)

# %%
# analisando as melhores métricas encontradas para o modelo
best_metrics(threshold = 0.70, predict = predict[:, 0], y = y[:, 0])
# Out:
# Matriz de Confusão:
#  [[14  3]
#  [ 2  9]]
# Acurácia: 0.8214285714285714
# Precisão 0.75
# Sensibilidade: 0.8181818181818182
# F1_Score: 0.7826086956521738

# %%
# analisando as melhores métricas encontradas para o modelo
best_metrics(threshold = 0.70, predict = predict[:, 1], y = y[:, 1])
# Out:
# Matriz de Confusão:
#  [[10  3]
#  [ 2 13]]
# Acurácia: 0.8214285714285714
# Precisão 0.8125
# Sensibilidade: 0.8666666666666667
# F1_Score: 0.8387096774193549

# %%
# visualizando o ganho de acurácia durante o treinamento
plt.figure(figsize = (15,5))
plt.subplot(1, 2, 1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('model-accuracy')

# visualizando o decaimento da função de custo durante o treinamento 
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('model-loss')

# %% [markdown]
# ### Algoritmo Grad CAM

# %%
import urllib.request as url

link = 'https://raw.githubusercontent.com/Alyssonmach/class-activation-maps/main/assets/grad_cam.py'
file_ = 'grad_cam.py'
url.urlretrieve(link, file_)

from grad_cam import get_img_array, make_gradcam_heatmap, save_and_display_gradcam

# %%
# tamanho padrão das imagens do modelo
img_size = (256, 256)
# importando os parâmetros de pré-processamento da rede
preprocess_input = tf.keras.applications.inception_v3.preprocess_input
# definindo a última camada da rede a ser considerada
last_conv_layer = 'mixed7'
model_builder = model
# removendo a função de ativação da última camada
model_builder.layers[-1].activation = None

# %%
img, lbl = x[1], y[1]

img_path = tf.keras.preprocessing.image.array_to_img(img)

# preparando a imagem
img_array = preprocess_input(get_img_array(img_path, img_size))

# obtendo a predição do modelo
preds = model_builder.predict(img_array)
print('Classe prevista: {}'.format(lbl))

# gerando o mapa de ativação de classe (Grad-Cam)
heatmap = make_gradcam_heatmap(img_array, model_builder, last_conv_layer,
                               pred_index = 1)

# resultado final do algoritmo Grad-Cam
heatmap = save_and_display_gradcam(img_path, heatmap, cam_path = 'image1.png')
# Out:
# Classe prevista: [1. 0.]

# %%
img, lbl = x[5], y[5]

img_path = tf.keras.preprocessing.image.array_to_img(img)

# preparando a imagem
img_array = preprocess_input(get_img_array(img_path, img_size))

# obtendo a predição do modelo
preds = model_builder.predict(img_array)
print('Classe prevista: {}'.format(lbl))

# gerando o mapa de ativação de classe (Grad-Cam)
heatmap = make_gradcam_heatmap(img_array, model_builder, last_conv_layer,
                               pred_index = 1)

# resultado final do algoritmo Grad-Cam
heatmap = save_and_display_gradcam(img_path, heatmap, cam_path = 'image1.png')
# Out:
# Classe prevista: [1. 0.]

# %%
img, lbl = x[10], y[10]

img_path = tf.keras.preprocessing.image.array_to_img(img)

# preparando a imagem
img_array = preprocess_input(get_img_array(img_path, img_size))

# obtendo a predição do modelo
preds = model_builder.predict(img_array)
print('Classe prevista: {}'.format(lbl))

# gerando o mapa de ativação de classe (Grad-Cam)
heatmap = make_gradcam_heatmap(img_array, model_builder, last_conv_layer,
                               pred_index = 1)

# resultado final do algoritmo Grad-Cam
heatmap = save_and_display_gradcam(img_path, heatmap, cam_path = 'image1.png')
# Out:
# Classe prevista: [1. 0.]

# %%
img, lbl = x[11], y[11]

img_path = tf.keras.preprocessing.image.array_to_img(img)

# preparando a imagem
img_array = preprocess_input(get_img_array(img_path, img_size))

# obtendo a predição do modelo
preds = model_builder.predict(img_array)
print('Classe prevista: {}'.format(lbl))

# gerando o mapa de ativação de classe (Grad-Cam)
heatmap = make_gradcam_heatmap(img_array, model_builder, last_conv_layer,
                               pred_index = 1)

# resultado final do algoritmo Grad-Cam
heatmap = save_and_display_gradcam(img_path, heatmap, cam_path = 'image1.png')
# Out:
# Classe prevista: [1. 0.]

# %% [markdown]
# ### Visualizando a arquitetura do modelo

# %%
# visualizando a arquitetura do modelo
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None,